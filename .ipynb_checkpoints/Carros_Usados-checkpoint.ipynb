# %%
import pandas as pd
import seaborn as sns

# %%
df= pd.read_csv('cars.csv')

# %%
df
# Out:
#          make model  priceUSD  year     condition  mileage(kilometers)  \
# 0       mazda     2      5500  2008  with mileage             162000.0
# 1       mazda     2      5350  2009  with mileage             120000.0
# 2       mazda     2      7000  2009  with mileage              61000.0
# 3       mazda     2      3300  2003  with mileage             265000.0
# 4       mazda     2      5200  2008  with mileage              97183.0
# ...       ...   ...       ...   ...           ...                  ...
# 56239  lancia  zeta      3650  2000  with mileage             290000.0
# 56240  lancia  zeta      4100  1999  with mileage             340000.0
# 56241  lancia  zeta      3600  1997  with mileage             354000.0
# 56242  lancia  zeta      3000  1997  with mileage             350000.0
# 56243  lancia  zeta      2950  1996  with mileage                  3.0
#
#       fuel_type  volume(cm3)     color transmission         drive_unit segment
# ...

# %%
df.describe()
# Out:
#             priceUSD          year  mileage(kilometers)   volume(cm3)
# count   56244.000000  56244.000000         5.624400e+04  56197.000000
# mean     7415.456440   2003.454840         2.443956e+05   2104.860615
# std      8316.959261      8.144247         3.210307e+05    959.201633
# min        48.000000   1910.000000         0.000000e+00    500.000000
# 25%      2350.000000   1998.000000         1.370000e+05   1600.000000
# 50%      5350.000000   2004.000000         2.285000e+05   1996.000000
# 75%      9807.500000   2010.000000         3.100000e+05   2300.000000
# max    235235.000000   2019.000000         9.999999e+06  20000.000000

# %% [markdown]
# ## kilometragem parece ter valores bem altos

# %%
sns.boxplot(df['mileage(kilometers)'])
# Out:
# C:\Users\Zoio\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.8_qbz5n2kfra8p0\LocalCache\local-packages\Python38\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='mileage(kilometers)'>

# %%
sns.set_style('darkgrid')

# %%
sns.histplot(df['mileage(kilometers)'], cumulative=True ,stat='probability', kde=True)
# Out:
# <AxesSubplot:xlabel='mileage(kilometers)', ylabel='Probability'>

# %%
df['mileage(kilometers)'].quantile(0.95)
# Out:
# 431000.0

# %%
df['mileage(kilometers)'].max()
# Out:
# 9999999.0

# %%
df.loc[df['mileage(kilometers)']>431000]
# Out:
#           make   model  priceUSD  year     condition  mileage(kilometers)  \
# 477      mazda       6      4000  2003  with mileage             440000.0
# 517      mazda       6      4100  2003  with mileage             450000.0
# 695    renault      11       400  1986  with mileage             999999.0
# 707    renault      19       784  1993  with mileage             449766.0
# 771    renault      19       600  1995  with mileage            2500000.0
# ...        ...     ...       ...   ...           ...                  ...
# 55969     opel  zafira      3500  2000  with mileage             444444.0
# 56055     opel  zafira      4000  2001  with mileage             463111.0
# 56113     opel  zafira      4850  2004  with mileage            4444444.0
# 56160     opel  zafira      4400  2002  with mileage            3333333.0
# 56230   lancia    zeta      3750  1998  with mileage            3333333.0
#
#       fuel_type  volume(cm3)   color transmission         drive_unit segment
# ...

# %%
df['make'].value_counts()
# Out:
# volkswagen      6861
# audi            4030
# bmw             4013
# opel            3779
# renault         3713
#                 ...
# roewe              1
# jac                1
# mclaren            1
# aston-martin       1
# asia               1
# Name: make, Length: 96, dtype: int64

# %%
df.loc[df['make']=='tesla']
# Out:
#         make    model  priceUSD  year     condition  mileage(kilometers)  \
# 34494  tesla  model-3     86353  2019  with mileage                 50.0
# 34495  tesla  model-s     56000  2015  with mileage              60000.0
# 34496  tesla  model-s     44000  2014  with mileage              62000.0
# 34497  tesla  model-s    116994  2018  with mileage              49000.0
# 34498  tesla  model-s     67900  2015  with mileage              52000.0
# 34499  tesla  model-s     48000  2014  with mileage             128000.0
# 34500  tesla  model-s     39999  2013  with mileage              33000.0
# 34501  tesla  model-s     43950  2013  with mileage              73000.0
# 34502  tesla  model-s     45000  2013  with mileage              99000.0
# 34503  tesla  model-s     58500  2016  with mileage              29000.0
# 34504  tesla  model-s     39900  2013  with mileage              34000.0
# 34505  tesla  model-x     92500  2017  with mileage               8000.0
# ...
